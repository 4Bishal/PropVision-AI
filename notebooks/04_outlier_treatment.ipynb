# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/processed/gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                society      sector  price  price_per_sqft  \
# 0         house      house number b-34    sector 5   0.80          8888.0
# 1          flat          godrej summit  sector 104   1.20          8298.0
# 2          flat        residency grand   sector 52   5.00          7692.0
# 3         house            independent   sector 22   4.75         20068.0
# 4          flat  signature global park  sohna road   0.56          6812.0
#
#      area                                       areaWithType  bedRoom  \
# 0   900.0  Plot area 900(83.61 sq.m.)Built Up area: 900 s...        2
# 1  1446.0                   Carpet area: 1446 (134.34 sq.m.)        3
# 2  6500.0                    Carpet area: 5200 (483.1 sq.m.)        5
# 3  2367.0  Plot area 263(219.9 sq.m.)Built Up area: 261 s...        7
# 4   822.0                     Carpet area: 822 (76.37 sq.m.)        2
#
#    bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
df.shape
# Out:
# (3677, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
# outliers on the basis of price column
sns.distplot(df['price'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\2797181776.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 814          house  arjun marg/ sector- 26 phase- 1/ golf course road
# 2651         house                                        independent
# 381          house                                        independent
# 1976         house                                     dlf city plots
# 3733         house                                   suncity township
# 722          house                             emaar the palm springs
# 1297         house                                        independent
# 538          house                                 vipul tatvam villa
# 3730         house                             luxury dlf city floors
# 3367         house                                     dlf city plots
# 796          house                                        independent
# 490          house                                        independent
# ...

# %%
# on the basis of price col we can say that there are some genuine outliers but there are some data erros as well

# %% [markdown]
# ### Price_per_sqft

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52592.612994
#  std       61150.458507
#  min       24489.000000
#  25%       28208.250000
#  50%       33368.500000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft
# Out:
#      property_type                              society      sector  price  \
# 33           house                     suncity township   sector 54   2.00
# 39           house                          independent   sector 12   3.50
# 43           house  international city by sobha phase 2  sector 109   6.20
# 69           house                          independent   sector 26   8.10
# 73           house                          independent    sector 9   1.10
# ...            ...                                  ...         ...    ...
# 3744         house                          independent   sector 24   1.45
# 3750         house                          independent   sector 43   6.50
# 3759         house                          independent   sector 43   8.50
# 3791         house                       uppal southend   sector 49   6.75
# 3793          flat                      emaar digihomes   sector 62   4.25
#
#       price_per_sqft    area  \
# 33           30968.0   646.0
# ...

# %%
# outliers.to_excel('../testfolder/output_file.xlsx')

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\205471443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\3686006548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.906780
# std      12403.077309
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000]
# Out:
#      property_type                       society           sector  price  \
# 381          house                   independent        sector 26  26.00
# 394          house                           nul        sector 28  12.50
# 722          house        emaar the palm springs        sector 54  24.00
# 1223         house        emaar the palm springs        sector 54  14.00
# 1878         house                   independent        sector 25  16.00
# 1976         house                dlf city plots        sector 26  26.00
# 2041         house                unitech escape        sector 50  10.80
# 2459         house            cloudnine cottages  sohna road road   5.50
# 2538         house  project housing board colony        sector 31   8.00
# 2967         house                  malibu towne        sector 47   8.50
# 3148          flat                unitech vistas        sector 70   9.00
# 3153         house            emaar mgf marbella        sector 66  18.00
# ...

# %%
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# ### Area

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2947.723608
# std       23208.194102
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 231           flat  signature global solera 2  sector 107   0.51
# 787           flat      signature the roselia   sector 95   0.45
# 1544          flat          hcbs sports ville  sohna road   0.35
# 1607         house                independent   sector 50   5.00
# 3708          flat            ramsons kshitij   sector 95   0.31
#
#       price_per_sqft      area                           areaWithType  \
# 231              9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 787              7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 1544             4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 1607           232.0  215517.0             Plot area 2(1011.71 sq.m.)
# 3708             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 231         2         2       1       3.0       North    New Property
# ...

# %%
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)

# 818, 1796, 1123, 2, 2356, 115, 3649, 2503, 1471

# 943 , 424 , 2181 , 2197 , 1722 , 2288 . 2239 . 2079 , 214
# Out:
#      property_type                    society           sector  price  \
# 943          house                independent        sector 26  18.40
# 269          house  ganpati heights apartment        sector 13   1.25
# 424           flat                 rof ananda        sector 95   0.38
# 2181          flat                 rof ananda        sector 95   0.38
# 343          house      dlf city plot phase 4        sector 28  13.00
# 2197          flat              pyramid elite        sector 86   0.46
# 1722          flat                 rof ananda        sector 95   0.33
# 2288          flat      signature the serenas       sohna road   0.28
# 926          house                independent        sector 25   7.30
# 2239          flat            ramsons kshitij        sector 95   0.24
# 2079          flat                 rof ananda        sector 95   0.21
# 118          house                independent        sector 57   6.25
# ...

# %%
df.drop(index=[943, 424, 2181, 2197, 1722, 2288, 2239, 2079, 214], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society           sector  price  \
# 269          house  ganpati heights apartment        sector 13   1.25
# 343          house      dlf city plot phase 4        sector 28  13.00
# 926          house                independent        sector 25   7.30
# 118          house                independent        sector 57   6.25
# 965          house                independent        sector 43   5.50
# 447           flat                 godrej air        sector 85   2.50
# 3703         house       unitech aspen greens        sector 50   6.95
# 659           flat                godrej icon       sector 88a   1.75
# 2651         house                independent        sector 43  27.50
# 3056          flat             m3m golfestate        sector 65  13.20
# 2510         house                independent  sohna road road   5.50
#
#       price_per_sqft     area  \
# 269            151.0  82781.0
# 343           1992.0  65261.0
# 926           1560.0  46795.0
# ...

# %%
df.loc[269,'area'] = 115*9
df.loc[343,'area'] = 7250
df.loc[926,'area'] = 5800
df.loc[118,'area'] = 2660
df.loc[965,'area'] = 2850
df.loc[447,'area'] = 18122
df.loc[3703,'area'] = 2160
df.loc[659,'area'] = 1175
df.loc[2510,'area'] = 3500

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
 sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3633.000000
# mean      1952.837325
# std       1236.544563
# min        145.000000
# 25%       1260.000000
# 50%       1747.000000
# 75%       2329.000000
# max      18122.000000
# Name: area, dtype: float64

# %% [markdown]
# ### Bedroom

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3633.000000
# mean        3.333609
# std         1.830035
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 984          house                  independent   sector 54   5.00
# 627          house                  independent   sector 43   4.50
# 346          house                  independent  sector 17a   3.93
# 16           house                  independent  sector 17a   3.87
# 2062         house                  independent   sector 54   5.50
# 2939         house                private house   sector 55   7.05
# 928          house                  independent   sector 55   9.19
# 3617         house                  independent   sector 43  13.50
# 1777         house                  independent   sector 56  12.39
# 1724         house                  independent   sector 40  12.00
# 3367         house               dlf city plots   sector 26  20.00
# 3730         house       luxury dlf city floors   sector 26  20.00
# 3385         house                  independent   sector 11   4.50
# ...

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3588, 23)

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3588.000000
# mean        3.203735
# std         1.393968
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# ### Bathroom

# %%
sns.distplot(df['bathroom'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\2904465235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 2023         house  adani brahma samsara  sector 60  18.02         28200.0
# 196          house           independent  sector 24  11.00         28902.0
# 3346         house           independent  sector 39   7.00         10000.0
#
#         area                                       areaWithType  bedRoom  \
# 2023  6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 196   3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
# 3346  7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 2023        12      3+       3.0  North-East  Relatively New
# 196         11      3+       3.0        East    Old Property
# 3346        11      3+       4.0  South-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %%
df.head()
# Out:
#   property_type                society      sector  price  price_per_sqft  \
# 0         house      house number b-34    sector 5   0.80          8888.0
# 1          flat          godrej summit  sector 104   1.20          8298.0
# 2          flat        residency grand   sector 52   5.00          7692.0
# 3         house            independent   sector 22   4.75         20068.0
# 4          flat  signature global park  sohna road   0.56          6812.0
#
#      area                                       areaWithType  bedRoom  \
# 0   900.0  Plot area 900(83.61 sq.m.)Built Up area: 900 s...        2
# 1  1446.0                   Carpet area: 1446 (134.34 sq.m.)        3
# 2  6500.0                    Carpet area: 5200 (483.1 sq.m.)        5
# 3  2367.0  Plot area 263(219.9 sq.m.)Built Up area: 261 s...        7
# 4   822.0                     Carpet area: 822 (76.37 sq.m.)        2
#
#    bathroom balcony  floorNum      facing   agePossession  \
# ...

# %% [markdown]
# ### super built up area

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\4184943455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 186           flat       krrish provence estate  gwal pahari    7.5
# 2948          flat  bestech park view grand spa    sector 81    4.7
#
#       price_per_sqft     area                             areaWithType  \
# 186           7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
# 2948          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 186         5         6      3+      23.0  North-East  Relatively New
# 2948        4         4      3+      19.0       North  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 186               10000.0            NaN          NaN           0
# 2948               6926.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %% [markdown]
# ### built up area

# %%
sns.distplot(df['built_up_area'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 10000]
# Out:
#      property_type      society     sector  price  price_per_sqft     area  \
# 2651         house  independent  sector 43   27.5         24366.0  11286.0
#
#                       areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2651  Plot area 1254(1048.5 sq.m.)        6         7      3+       3.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 2651  North-East  Relatively New                  NaN        11286.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 2651          NaN           1             1           0           1       1
#
#       furnishing_type  luxury_score
# 2651                0            42

# %% [markdown]
# ### carpet area

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 447           flat      godrej air  sector 85    2.5          1379.0  18122.0
# 3056          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 447   Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
# 3056  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#           facing       agePossession  super_built_up_area  built_up_area  \
# 447   North-East  Under Construction                  NaN            NaN
# 3056       North      Moderately Old                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 447       18122.0           1             0           0           1       1
# 3056      11000.0           0             1           0           0       0
#
#       furnishing_type  luxury_score
# ...

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 447           flat      godrej air  sector 85    2.5          1380.0  18122.0
# 3056          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 447   Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
# 3056  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#           facing       agePossession  super_built_up_area  built_up_area  \
# 447   North-East  Under Construction                  NaN            NaN
# 3056       North      Moderately Old                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 447       18122.0           1             0           0           1       1
# 3056      11000.0           0             1           0           0       0
#
#       furnishing_type  luxury_score
# ...

# %%
df.head()
# Out:
#   property_type                society      sector  price  price_per_sqft  \
# 0         house      house number b-34    sector 5   0.80          8889.0
# 1          flat          godrej summit  sector 104   1.20          8299.0
# 2          flat        residency grand   sector 52   5.00          7692.0
# 3         house            independent   sector 22   4.75         20068.0
# 4          flat  signature global park  sohna road   0.56          6813.0
#
#      area                                       areaWithType  bedRoom  \
# 0   900.0  Plot area 900(83.61 sq.m.)Built Up area: 900 s...        2
# 1  1446.0                   Carpet area: 1446 (134.34 sq.m.)        3
# 2  6500.0                    Carpet area: 5200 (483.1 sq.m.)        5
# 3  2367.0  Plot area 263(219.9 sq.m.)Built Up area: 261 s...        7
# 4   822.0                     Carpet area: 822 (76.37 sq.m.)        2
#
#    bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
sns.distplot(df['luxury_score'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(df['luxury_score'])
# Out:
# <Axes: ylabel='luxury_score'>

# %%
df.shape
# Out:
# (3588, 23)

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\3958460563.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
df.head()
# Out:
#   property_type                society      sector  price  price_per_sqft  \
# 0         house      house number b-34    sector 5   0.80          8889.0
# 1          flat          godrej summit  sector 104   1.20          8299.0
# 2          flat        residency grand   sector 52   5.00          7692.0
# 3         house            independent   sector 22   4.75         20068.0
# 4          flat  signature global park  sohna road   0.56          6813.0
#
#      area                                       areaWithType  bedRoom  \
# 0   900.0  Plot area 900(83.61 sq.m.)Built Up area: 900 s...        2
# 1  1446.0                   Carpet area: 1446 (134.34 sq.m.)        3
# 2  6500.0                    Carpet area: 5200 (483.1 sq.m.)        5
# 3  2367.0  Plot area 263(219.9 sq.m.)Built Up area: 261 s...        7
# 4   822.0                     Carpet area: 822 (76.37 sq.m.)        2
#
#    bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(df['price_per_sqft'] , orient='h')
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 796          house                   independent   sector 26   20.0
# 1112         house                   independent   sector 55    5.0
# 1168         house                   independent   sector 28   12.0
# 1479         house                   independent  sector 105    9.9
# 1897         house                   independent   sector 26   19.0
# 2409         house  sushant lok 1 builder floors   sector 43   13.0
# 2412         house                dlf city plots   sector 26   19.0
# 2479         house                   independent   sector 25   13.0
# 2961         house                   independent   sector 43    9.5
#
#       price_per_sqft    area  \
# 796          44444.0  4500.0
# 1112         44444.0  1125.0
# 1168         42194.0  2844.0
# 1479         49500.0  2000.0
# 1897         42222.0  4500.0
# 2409         48148.0  2700.0
# 2412         42054.0  4518.0
# 2479         45710.0  2844.0
# ...

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.05)
# Out:
# np.float64(252.8666666666667)

# %%
df[(df['area']/df['bedRoom'])<250].sample(5)
# Out:
#      property_type                          society  \
# 2007         house                      independent
# 1557         house  ashok vihar phase iii extension
# 1939         house                      independent
# 934          house                      independent
# 1010          flat            pyramid urban homes 2
#
#                           sector  price  price_per_sqft    area  \
# 2007                   sector 17   0.32         22069.0   145.0
# 1557  sector 3 phase 3 extension   0.40          8889.0   450.0
# 1939             sohna road road   0.95          8920.0  1065.0
# 934                   sector 105   0.38          8444.0   450.0
# 1010                   sector 86   0.42          8485.0   495.0
#
#                           areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2007  Built Up area: 145 (13.47 sq.m.)        2         2       0       3.0
# 1557         Plot area 50(41.81 sq.m.)        7         4      3+       4.0
# ...

# %%
sns.lmplot(data=df , x='area' , y='bedRoom')

# %%
df['area_room_ratio'] = df['area'] / df['bedRoom']
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\1249168808.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area_room_ratio'] = df['area'] / df['bedRoom']

# %%
df[df['area_room_ratio'] < 250]['bedRoom'].value_counts()
# Out:
# bedRoom
# 2     47
# 3     33
# 5     28
# 4     17
# 6     17
# 9     15
# 8     12
# 7      8
# 10     8
# Name: count, dtype: int64

# %%
df = df[df['area_room_ratio'] > 100]

# %%
outliers_df = df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 3)]

# %%
outliers_df['bedRoom'] = round(outliers_df['bedRoom'] / outliers_df['floorNum'])
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\1649205732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['bedRoom'] = round(outliers_df['bedRoom'] / outliers_df['floorNum'])

# %%
df.update(outliers_df)

# %%
df['area_room_ratio'] = df['area'] / df['bedRoom']
# Out:
# C:\Users\Predator\AppData\Local\Temp\ipykernel_6592\1249168808.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area_room_ratio'] = df['area'] / df['bedRoom']

# %%
df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 4)]
# Out:
#      property_type               society            sector  price  \
# 780          house              shivpuri          sector 7   2.80
# 1835         house           independent          sector 7   1.16
# 1923         house           independent  sector 3 phase 2   0.85
# 1970         house           independent           manesar   1.10
# 2548         house           independent         sector 17   0.32
# 2575         house           independent  sector 3 phase 2   1.10
# 2596         house           independent         sector 11   3.50
# 2679         house           independent        sector 105   1.10
# 2794         house           independent         sector 12   2.50
# 3212         house           independent           manesar   0.80
# 3378         house  bhim nagar, sector 6          sector 6   0.85
# 3418         house           independent         sector 12   0.65
# 3741         house           independent          sector 2   0.98
#
#       price_per_sqft    area  \
# ...

# %%
df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 4)].shape
# Out:
# (13, 24)

# %%
df = df[~((df['area_room_ratio'] < 250) & (df['bedRoom'] > 4))]

# %%
sns.lmplot(data= df , x='area' , y='bedRoom')

# %%
df.to_csv('../data/processed/gurgaon_properties_outlier_treated.csv')
